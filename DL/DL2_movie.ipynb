# %%
import numpy as np
from tensorflow.keras.datasets import imdb
from tensorflow.keras.layers import Dense,Input
from tensorflow.keras.models import Sequential

# %%
(train_data,train_label),(test_data,test_label) = imdb.load_data(num_words = 10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
def vectorize_sequence(sequence,dimension=10000):
  results = np.zeros((len(sequence),dimension))
  for i,seq in enumerate(sequence):
    results[i,seq] = 1
  return results

# %%
x_train = vectorize_sequence(train_data)
x_test = vectorize_sequence(test_data)
y_train = np.asarray(train_label).astype('float32')
y_test = np.asarray(test_label).astype('float32')

# %%
model = Sequential()
model.add(Input(shape=(10000,)))
model.add(Dense(64,activation ='relu'))
model.add(Dense(32,activation = 'relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.compile(optimizer = 'adam',loss ='binary_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(x_train,y_train,epochs =20,batch_size =512,validation_split =0.3)
# Out:
# Epoch 1/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 98ms/step - accuracy: 0.8180 - loss: 0.4351 - val_accuracy: 0.8876 - val_loss: 0.2830
# Epoch 2/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 8s 174ms/step - accuracy: 0.9247 - loss: 0.2007 - val_accuracy: 0.8917 - val_loss: 0.2767
# Epoch 3/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.9578 - loss: 0.1292 - val_accuracy: 0.8856 - val_loss: 0.3052
# Epoch 4/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.9739 - loss: 0.0875 - val_accuracy: 0.8788 - val_loss: 0.3633
# Epoch 5/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - accuracy: 0.9856 - loss: 0.0565 - val_accuracy: 0.8764 - val_loss: 0.4076
# Epoch 6/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.9941 - loss: 0.0318 - val_accuracy: 0.8720 - val_loss: 0.4678
# Epoch 7/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.9985 - loss: 0.0168 - val_accuracy: 0.8685 - val_loss: 0.5234
# Epoch 8/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - accuracy: 0.9995 - loss: 0.0096 - val_accuracy: 0.8671 - val_loss: 0.5711
# Epoch 9/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 6s 106ms/step - accuracy: 0.9999 - loss: 0.0055 - val_accuracy: 0.8703 - val_loss: 0.6066
# Epoch 10/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.9999 - loss: 0.0035 - val_accuracy: 0.8675 - val_loss: 0.6366
# Epoch 11/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.8683 - val_loss: 0.6629
# Epoch 12/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.8691 - val_loss: 0.6857
# Epoch 13/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.8675 - val_loss: 0.7045
# Epoch 14/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.8681 - val_loss: 0.7221
# Epoch 15/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - accuracy: 1.0000 - loss: 9.2593e-04 - val_accuracy: 0.8680 - val_loss: 0.7389
# Epoch 16/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - accuracy: 1.0000 - loss: 7.6861e-04 - val_accuracy: 0.8687 - val_loss: 0.7525
# Epoch 17/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - accuracy: 1.0000 - loss: 6.4289e-04 - val_accuracy: 0.8677 - val_loss: 0.7657
# Epoch 18/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 1.0000 - loss: 5.4691e-04 - val_accuracy: 0.8683 - val_loss: 0.7793
# Epoch 19/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 1.0000 - loss: 4.7026e-04 - val_accuracy: 0.8676 - val_loss: 0.7903
# Epoch 20/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - accuracy: 1.0000 - loss: 4.0943e-04 - val_accuracy: 0.8680 - val_loss: 0.8023

# %%
loss,accuracy = model.evaluate(x_test,y_test)
print("Test Accuracy:",accuracy)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8554 - loss: 0.8724
# Test Accuracy: 0.855400025844574

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │       640,064 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,926,533 (7.35 MB)
#  Trainable params: 642,177 (2.45 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 1,284,356 (4.90 MB)
